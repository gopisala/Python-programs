# %%
#FUNCTION(Formal and actual arguments)
def add(a,b):
  c=a+b
  print(c)
x=10
y=20
add(x,y)
# Out:
# 30

# %%
#POSITIONAL ARGUMENTS
def sub(x,y):
  print(x-y)
sub(20,30)
# Out:
# -10

# %%
# ERROR:Positional arguments
def sub(x,y):
  print(x-y)
sub(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1494/2765706058.py in <cell line: 0>()
#       2 def sub(x,y):
#       3   print(x-y)
# ----> 4 sub(10,20,30)
#
# TypeError: sub() takes 2 positional arguments but 3 were given

# %%
#KEYWORD ARGUMENTS
def cart(product,price):
  print("Product is :",product)
  print("cost is:",price)
cart(product="bangle",price=20000)
# Out:
# Product is : bangle
# cost is: 20000

# %%
#keyword arguments
def cart(product,price):
   print("Product is :",product)
   print("cost is:",price)
cart(product="handbag",price=100000)
# Out:
# Product is : handbag
# cost is: 100000

# %%
#KEYWORD ARGUMENTS
def cart(product,price):
  print("Product is:",product)
  print("cost is:",price)
cart(price=1200,product="shirt")
# Out:
# Product is: shirt
# cost is: 1200

# %%
#Defualt argument
def cart(product,price=40.0):
  print("Product is:",product)
  print("Cost is:",price)
cart(product="pen")
# Out:
# Product is: pen
# Cost is: 40.0

# %%
#default arguments
def cart(product,price=40.0):
  print("product is:",product)
  print("cost is:",price)
cart(product="handbag",price=10000)
# Out:
# product is: handbag
# cost is: 10000

# %%
# Default arguments
def cart(product,price=40.0):
  print("product is:",product)
  print("cost is :",price)
cart(price=500,product="shirt")
# Out:
# product is: shirt
# cost is : 500

# %%
#variable length argument
def m(x):
   print(x)
m(10)
# Out:
# 10

# %%
def m(x):
  print(x)
m(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1494/127779254.py in <cell line: 0>()
#       1 def m(x):
#       2   print(x)
# ----> 3 m(10,20)
#
# TypeError: m() takes 1 positional argument but 2 were given

# %%
#variable length argument
def m(*x):
  print(x)
m(10)
# Out:
# (10,)

# %%
#variable length argument
def m(*x):
  print(x)
m(10,20)
# Out:
# (10, 20)

# %%
def m(*x):
   print(x)
m(10,20,30)
# Out:
# (10, 20, 30)

# %%
#LAMBDA
# anonymous function
s=lambda a:a*a
x=s(4)
print(x)
# Out:
# 16

# %%
#to find sum of two values by using normal function
def add(x,y):
    return x+y
b=add(10,20)
print(b)
# Out:
# 30

# %%
#to find square by using a ormal function
def square(t):
  return t*t
s=square(2)
print(s)
# Out:
# 4

# %%
#to find sum of two values by using anonymus functtion
add=lambda x,y:x+y
b=add(1,2)
print(b)
# Out:
# 3

# %%
add=lambda x,y:x+y
b=sub(3,2)
print(b)
# Out:
# 1
# None

# %%
#MAP(P1,P2)FUNCTION


#Find square by using map function

without_cost=[100,200,300,400]
with_cost=map(lambda x:x+10,without_cost)
x=list(with_cost)
print("withoutcost:",without_cost)
print("with cost:",with_cost)
# Out:
# withoutcost: [100, 200, 300, 400]
# with cost: <map object at 0x79a3e0fac3a0>

# %%
# FILTER (FUNCTION,SEQUENCE)

#example by using filter function
items_cost=[999,888,1100,1200,1300,777]
gt_thousand=filter(lambda x:x>1000,items_cost)

x=list(gt_thousand)
print("Eligible for discount:",x)
# Out:
# Eligible for discount: [1100, 1200, 1300]

# %%
#REDDUCE (FUNCTION,SEQUENCE)

#reeduce
from functools import reduce

items_cost=[111,222,333,444]
total_cost=reduce(lambda x,y:x+y, items_cost)
print(total_cost)
# Out:
# 1110
