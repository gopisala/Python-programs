# %%
sal=10000
sal=20000
print("my salary is:",sal)
# Out:
# my salary is: 20000

# %%
print("hello world")
# Out:
# hello world

# %%
student_id=101
print(student_id)
# Out:
# 101

# %%
$tudent_id=101
print($tudent_id)
# Out:
#   File "/tmp/ipykernel_2825/75988222.py", line 1
#     $tudent_id=101
#     ^
# SyntaxError: invalid syntax

# %%
student_id123=101
print(student_id123)
# Out:
# 101

# %%
123tudent_id=101
print(123tudent_id)
# Out:
#   File "/tmp/ipykernel_1133/3672321147.py", line 1
#     123tudent_id=101
#       ^
# SyntaxError: invalid decimal literal

# %%
value=10
print(value)
# Out:
# 10

# %%
value=10
print(VALUE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1133/4225647560.py in <cell line: 0>()
#       1 value=10
# ----> 2 print(VALUE)
#
# NameError: name 'VALUE' is not defined

# %%
if=10
print(if)
# Out:
#   File "/tmp/ipykernel_1133/2430702992.py", line 1
#     if=10
#       ^
# SyntaxError: invalid syntax

# %%
student id=101
print(student id)
# Out:
#   File "/tmp/ipykernel_1133/1954475188.py", line 1
#     student id=101
#             ^
# SyntaxError: invalid syntax

# %%
#this is a python program
print("Welcome to python programming")
# Out:
# Welcome to python programming

# %%
"""this is simple program"""
print("hi")
# Out:
# hi

# %%
age=16
print(age)
# Out:
# 16

# %%
name="raja"
age=16
print(name)
print(age)
# Out:
# raja
# 16

# %%
name="raja"
age=12
print(name,age)
# Out:
# raja 12

# %%
name="raja"
print("i am:",name)
# Out:
# i am: raja

# %%
a,b,c=1,2,3
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
a=b=c=3
print(a)
print(b)
print(c)
# Out:
# 3
# 3
# 3

# %%
salary=10000
print("my salary is:",salary)
# Out:
# my salary is: 10000
