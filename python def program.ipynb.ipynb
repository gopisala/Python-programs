# %%
def display():

  display=input("Enter the name:")

print(display)
# Out:
# <function display at 0x7d4ac32163e0>

# %%
display=input("Enter the name")
print(f"my name is {display}")
# Out:
# Enter the namegopika
# my name is gopika

# %%
display=input("Enter one parameterised function:")
def testing():
  print(f"one parameterised function is {display}")
testing()
# Out:
# Enter one parameterised function:10
# one parameterised function is 10

# %%
display=input("Enter one parameterised function:")
def testing(dispaly
 print("10")
# Out:
# Enter one parameterised function:10

# %%
display=input("Enteer one parameterised function:")
print(f"one parameterised function is {display}")
# Out:
# Enteer one parameterised function:10
# one parameterised function is 10

# %%
def sat():
display=input("Enter one parameterised function:")
  print(display)
sat()
# Out:
#   File "/tmp/ipykernel_2256/639910689.py", line 2
#     display=input("Enter one parameterised function:")
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
def sat():
  a=int(input("Enter the first value"))
  b=int(input("Enter the second value"))
  c=a+b
  print(c)
sat()
# Out:
# Enter the first value22
# Enter the second value3
# 25

# %%
  a=int(input("Enter the first value"))
  b=int(input("Enter the second value"))
  c=a+b
def sat():
  print(c)
sat()
# Out:
#   File "/tmp/ipykernel_2256/3805799543.py", line 5
#     print(c)
#     ^
# IndentationError: expected an indented block after function definition on line 4

# %%
def sat():
  display=input("Enter the name:")
  print(f"My name is {display}")
sat()
# Out:
# Enter the name:gopika
# My name is gopika
