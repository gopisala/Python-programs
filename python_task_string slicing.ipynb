# %%
#PYTHON SLICING-10 PROGRAM WITH SOLUTIONS
#print first 5 characters
s='programming'
print(s[:5])
# Out:
# progr

# %%
#Print last 4 characters
s='programming'
print(s[-4:])
# Out:
# ming

# %%
#Reverse string
s='Python'
print(s[::-1])
# Out:
# nohtyP

# %%
#Every second character
s='programming'
print(s[::2])
# Out:
# pormig

# %%
#characters 3 to 7
s='programming'
print(s[2:7])
# Out:
# ogram

# %%
#Remove first character
s='python'
print(s[1:])

# %%
#remove last character
s='python'
print(s[:-1])
# Out:
# pytho

# %%
#last 5 reversed
s='programming'
print(s[-5:][::-1])
# Out:
# gnimm

# %%
#Middle 4 characters
s='education'
mid=len(s)//2
print(s[mid-3:mid+2])
# Out:
# ducat
